# %% [markdown]
# - Check for Colab Env
# > if we are in colab env we need to get the data + scripts from github or somewhere

# %%
import os
if "COLAB_GPU" in os.environ:
    _useMultiProcessing = False
    os.system("git clone https://github.com/zaxo7/UNet-Playground.git")
    os.chdir("/content/UNet-Playground/")
else:
    _useMultiProcessing = True
    
if "PAPERSPACE_FQDN" in os.environ:
    # !apt update
    # !apt install libgl1 -y
    # !pip install opencv-python
    #!git pull
# Out:
# Get:1 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Hit:2 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:4 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [881 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [2420 kB]
# Get:7 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [1979 kB]
# Get:8 http://security.ubuntu.com/ubuntu focal-security/restricted amd64 Packages [1331 kB]33m
# Get:9 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [27.5 kB]33m
# Get:10 http://archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [30.3 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 Packages [1411 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1161 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal-backports/universe amd64 Packages [27.1 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal-backports/main amd64 Packages [54.2 kB]
# Fetched 9657 kB in 2s (5474 kB/s)33m
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 78 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libdrm-amdgpu1 libdrm-common libdrm-intel1 libdrm-nouveau2 libdrm-radeon1
#   libdrm2 libelf1 libgl1-mesa-dri libglapi-mesa libglvnd0 libglx-mesa0 libglx0
#   libllvm12 libpciaccess0 libsensors-config libsensors5 libvulkan1
#   libwayland-client0 libx11-6 libx11-data libx11-xcb1 libxau6 libxcb-dri2-0
#   libxcb-dri3-0 libxcb-glx0 libxcb-present0 libxcb-randr0 libxcb-shm0
#   libxcb-sync1 libxcb-xfixes0 libxcb1 libxdmcp6 libxext6 libxfixes3
#   libxshmfence1 libxxf86vm1 mesa-vulkan-drivers
# Suggested packages:
#   pciutils lm-sensors
# The following NEW packages will be installed:
#   libdrm-amdgpu1 libdrm-common libdrm-intel1 libdrm-nouveau2 libdrm-radeon1
#   libdrm2 libelf1 libgl1 libgl1-mesa-dri libglapi-mesa libglvnd0 libglx-mesa0
#   libglx0 libllvm12 libpciaccess0 libsensors-config libsensors5 libvulkan1
#   libwayland-client0 libx11-6 libx11-data libx11-xcb1 libxau6 libxcb-dri2-0
#   libxcb-dri3-0 libxcb-glx0 libxcb-present0 libxcb-randr0 libxcb-shm0
#   libxcb-sync1 libxcb-xfixes0 libxcb1 libxdmcp6 libxext6 libxfixes3
#   libxshmfence1 libxxf86vm1 mesa-vulkan-drivers
# 0 upgraded, 38 newly installed, 0 to remove and 78 not upgraded.
# Need to get 37.2 MB of archives.
# After this operation, 528 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 libelf1 amd64 0.176-1.1build1 [44.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libdrm-common all 2.4.107-8ubuntu1~20.04.2 [5396 B]
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libdrm2 amd64 2.4.107-8ubuntu1~20.04.2 [34.1 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/main amd64 libxau6 amd64 1:1.0.9-0ubuntu1 [7488 B]
# Get:5 http://archive.ubuntu.com/ubuntu focal/main amd64 libxdmcp6 amd64 1:1.1.3-0ubuntu1 [10.6 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb1 amd64 1.14-2 [44.7 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libx11-data all 2:1.6.9-2ubuntu1.2 [113 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libx11-6 amd64 2:1.6.9-2ubuntu1.2 [575 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal/main amd64 libxext6 amd64 2:1.3.4-0ubuntu1 [29.1 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libdrm-amdgpu1 amd64 2.4.107-8ubuntu1~20.04.2 [18.6 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal/main amd64 libpciaccess0 amd64 0.16-0ubuntu1 [17.9 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libdrm-intel1 amd64 2.4.107-8ubuntu1~20.04.2 [60.3 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libdrm-nouveau2 amd64 2.4.107-8ubuntu1~20.04.2 [16.6 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libdrm-radeon1 amd64 2.4.107-8ubuntu1~20.04.2 [19.7 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglapi-mesa amd64 21.2.6-0ubuntu0.1~20.04.2 [27.4 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libllvm12 amd64 1:12.0.0-3ubuntu1~20.04.5 [18.8 MB]
# Get:17 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsensors-config all 1:3.6.0-2ubuntu1.1 [6052 B]3m
# Get:18 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsensors5 amd64 1:3.6.0-2ubuntu1.1 [27.2 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal/main amd64 libvulkan1 amd64 1.2.131.2-1 [93.3 kB]
# Get:20 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgl1-mesa-dri amd64 21.2.6-0ubuntu0.1~20.04.2 [11.0 MB]
# Get:21 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libx11-xcb1 amd64 2:1.6.9-2ubuntu1.2 [9372 B]33m
# Get:22 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb-dri2-0 amd64 1.14-2 [6920 B]
# Get:23 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb-dri3-0 amd64 1.14-2 [6552 B]
# Get:24 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb-glx0 amd64 1.14-2 [22.1 kB]
# Get:25 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb-present0 amd64 1.14-2 [5560 B]
# Get:26 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb-shm0 amd64 1.14-2 [5584 B]
# Get:27 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb-sync1 amd64 1.14-2 [8884 B]
# Get:28 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb-xfixes0 amd64 1.14-2 [9296 B]
# Get:29 http://archive.ubuntu.com/ubuntu focal/main amd64 libxfixes3 amd64 1:5.0.3-2 [10.9 kB]
# Get:30 http://archive.ubuntu.com/ubuntu focal/main amd64 libxshmfence1 amd64 1.3-1 [5028 B]
# Get:31 http://archive.ubuntu.com/ubuntu focal/main amd64 libxxf86vm1 amd64 1:1.1.4-1build1 [10.2 kB]
# Get:32 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglx-mesa0 amd64 21.2.6-0ubuntu0.1~20.04.2 [137 kB]
# Get:33 http://archive.ubuntu.com/ubuntu focal/main amd64 libwayland-client0 amd64 1.18.0-1 [23.9 kB]
# Get:34 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb-randr0 amd64 1.14-2 [16.3 kB]
# Get:35 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 mesa-vulkan-drivers amd64 21.2.6-0ubuntu0.1~20.04.2 [5788 kB]
# Get:36 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglvnd0 amd64 1.3.2-1~ubuntu0.20.04.2 [48.1 kB]
# Get:37 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglx0 amd64 1.3.2-1~ubuntu0.20.04.2 [32.5 kB]
# Get:38 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgl1 amd64 1.3.2-1~ubuntu0.20.04.2 [85.8 kB]
# Fetched 37.2 MB in 51s (734 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 38.)
# debconf: falling back to frontend: Readline
# Extracting templates from packages: 100%
#
# 78Selecting previously unselected package libelf1:amd64.
# (Reading database ... 41944 files and directories currently installed.)
# Preparing to unpack .../00-libelf1_0.176-1.1build1_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking libelf1:amd64 (0.176-1.1build1) ...
# 7Progress: [  1%] [..........................................................] 8Selecting previously unselected package libdrm-common.
# Preparing to unpack .../01-libdrm-common_2.4.107-8ubuntu1~20.04.2_all.deb ...
# Unpacking libdrm-common (2.4.107-8ubuntu1~20.04.2) ...
# 7Progress: [  3%] [#.........................................................] 8Selecting previously unselected package libdrm2:amd64.
# Preparing to unpack .../02-libdrm2_2.4.107-8ubuntu1~20.04.2_amd64.deb ...
# 7Progress: [  3%] [#.........................................................] 8Unpacking libdrm2:amd64 (2.4.107-8ubuntu1~20.04.2) ...
# Selecting previously unselected package libxau6:amd64.
# Preparing to unpack .../03-libxau6_1%3a1.0.9-0ubuntu1_amd64.deb ...
# 7Progress: [  5%] [##........................................................] 8Unpacking libxau6:amd64 (1:1.0.9-0ubuntu1) ...
# 7Progress: [  5%] [###.......................................................] 8Selecting previously unselected package libxdmcp6:amd64.
# Preparing to unpack .../04-libxdmcp6_1%3a1.1.3-0ubuntu1_amd64.deb ...
# Unpacking libxdmcp6:amd64 (1:1.1.3-0ubuntu1) ...
# 7Progress: [  7%] [###.......................................................] 8Selecting previously unselected package libxcb1:amd64.
# Preparing to unpack .../05-libxcb1_1.14-2_amd64.deb ...
# 7Progress: [  7%] [####......................................................] 8Unpacking libxcb1:amd64 (1.14-2) ...
# Selecting previously unselected package libx11-data.
# Preparing to unpack .../06-libx11-data_2%3a1.6.9-2ubuntu1.2_all.deb ...
# 7Progress: [  8%] [####......................................................] 8Unpacking libx11-data (2:1.6.9-2ubuntu1.2) ...
# 7Progress: [  9%] [#####.....................................................] 8Selecting previously unselected package libx11-6:amd64.
# Preparing to unpack .../07-libx11-6_2%3a1.6.9-2ubuntu1.2_amd64.deb ...
# Unpacking libx11-6:amd64 (2:1.6.9-2ubuntu1.2) ...
# 7Progress: [ 10%] [######....................................................] 8Selecting previously unselected package libxext6:amd64.
# Preparing to unpack .../08-libxext6_2%3a1.3.4-0ubuntu1_amd64.deb ...
# 7Progress: [ 11%] [######....................................................] 8Unpacking libxext6:amd64 (2:1.3.4-0ubuntu1) ...
# Selecting previously unselected package libdrm-amdgpu1:amd64.
# Preparing to unpack .../09-libdrm-amdgpu1_2.4.107-8ubuntu1~20.04.2_amd64.deb ...
# 7Progress: [ 12%] [#######...................................................] 8Unpacking libdrm-amdgpu1:amd64 (2.4.107-8ubuntu1~20.04.2) ...
# 7Progress: [ 13%] [#######...................................................] 8Selecting previously unselected package libpciaccess0:amd64.
# Preparing to unpack .../10-libpciaccess0_0.16-0ubuntu1_amd64.deb ...
# Unpacking libpciaccess0:amd64 (0.16-0ubuntu1) ...
# 7Progress: [ 14%] [########..................................................] 8Selecting previously unselected package libdrm-intel1:amd64.
# Preparing to unpack .../11-libdrm-intel1_2.4.107-8ubuntu1~20.04.2_amd64.deb ...
# 7Progress: [ 15%] [########..................................................] 8Unpacking libdrm-intel1:amd64 (2.4.107-8ubuntu1~20.04.2) ...
# Selecting previously unselected package libdrm-nouveau2:amd64.
# Preparing to unpack .../12-libdrm-nouveau2_2.4.107-8ubuntu1~20.04.2_amd64.deb ...
# 7Progress: [ 16%] [#########.................................................] 8Unpacking libdrm-nouveau2:amd64 (2.4.107-8ubuntu1~20.04.2) ...
# Selecting previously unselected package libdrm-radeon1:amd64.
# Preparing to unpack .../13-libdrm-radeon1_2.4.107-8ubuntu1~20.04.2_amd64.deb ...
# 7Progress: [ 18%] [##########................................................] 8Unpacking libdrm-radeon1:amd64 (2.4.107-8ubuntu1~20.04.2) ...
# 7Progress: [ 18%] [##########................................................] 8Selecting previously unselected package libglapi-mesa:amd64.
# Preparing to unpack .../14-libglapi-mesa_21.2.6-0ubuntu0.1~20.04.2_amd64.deb ...
# Unpacking libglapi-mesa:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# 7Progress: [ 20%] [###########...............................................] 8Selecting previously unselected package libllvm12:amd64.
# Preparing to unpack .../15-libllvm12_1%3a12.0.0-3ubuntu1~20.04.5_amd64.deb ...
# 7Progress: [ 20%] [###########...............................................] 8Unpacking libllvm12:amd64 (1:12.0.0-3ubuntu1~20.04.5) ...
# Selecting previously unselected package libsensors-config.
# Preparing to unpack .../16-libsensors-config_1%3a3.6.0-2ubuntu1.1_all.deb ...
# 7Progress: [ 22%] [############..............................................] 8Unpacking libsensors-config (1:3.6.0-2ubuntu1.1) ...
# 7Progress: [ 22%] [############..............................................] 8Selecting previously unselected package libsensors5:amd64.
# Preparing to unpack .../17-libsensors5_1%3a3.6.0-2ubuntu1.1_amd64.deb ...
# Unpacking libsensors5:amd64 (1:3.6.0-2ubuntu1.1) ...
# 7Progress: [ 24%] [#############.............................................] 8Selecting previously unselected package libvulkan1:amd64.
# Preparing to unpack .../18-libvulkan1_1.2.131.2-1_amd64.deb ...
# 7Progress: [ 24%] [##############............................................] 8Unpacking libvulkan1:amd64 (1.2.131.2-1) ...
# Selecting previously unselected package libgl1-mesa-dri:amd64.
# Preparing to unpack .../19-libgl1-mesa-dri_21.2.6-0ubuntu0.1~20.04.2_amd64.deb ...
# 7Progress: [ 25%] [##############............................................] 8Unpacking libgl1-mesa-dri:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# 7Progress: [ 26%] [###############...........................................] 8Selecting previously unselected package libx11-xcb1:amd64.
# Preparing to unpack .../20-libx11-xcb1_2%3a1.6.9-2ubuntu1.2_amd64.deb ...
# Unpacking libx11-xcb1:amd64 (2:1.6.9-2ubuntu1.2) ...
# 7Progress: [ 27%] [###############...........................................] 8Selecting previously unselected package libxcb-dri2-0:amd64.
# Preparing to unpack .../21-libxcb-dri2-0_1.14-2_amd64.deb ...
# 7Progress: [ 28%] [################..........................................] 8Unpacking libxcb-dri2-0:amd64 (1.14-2) ...
# Selecting previously unselected package libxcb-dri3-0:amd64.
# Preparing to unpack .../22-libxcb-dri3-0_1.14-2_amd64.deb ...
# 7Progress: [ 29%] [#################.........................................] 8Unpacking libxcb-dri3-0:amd64 (1.14-2) ...
# 7Progress: [ 30%] [#################.........................................] 8Selecting previously unselected package libxcb-glx0:amd64.
# Preparing to unpack .../23-libxcb-glx0_1.14-2_amd64.deb ...
# Unpacking libxcb-glx0:amd64 (1.14-2) ...
# 7Progress: [ 31%] [##################........................................] 8Selecting previously unselected package libxcb-present0:amd64.
# Preparing to unpack .../24-libxcb-present0_1.14-2_amd64.deb ...
# 7Progress: [ 32%] [##################........................................] 8Unpacking libxcb-present0:amd64 (1.14-2) ...
# Selecting previously unselected package libxcb-shm0:amd64.
# Preparing to unpack .../25-libxcb-shm0_1.14-2_amd64.deb ...
# 7Progress: [ 33%] [###################.......................................] 8Unpacking libxcb-shm0:amd64 (1.14-2) ...
# Selecting previously unselected package libxcb-sync1:amd64.
# Preparing to unpack .../26-libxcb-sync1_1.14-2_amd64.deb ...
# 7Progress: [ 35%] [####################......................................] 8Unpacking libxcb-sync1:amd64 (1.14-2) ...
# 7Progress: [ 35%] [####################......................................] 8Selecting previously unselected package libxcb-xfixes0:amd64.
# Preparing to unpack .../27-libxcb-xfixes0_1.14-2_amd64.deb ...
# Unpacking libxcb-xfixes0:amd64 (1.14-2) ...
# 7Progress: [ 37%] [#####################.....................................] 8Selecting previously unselected package libxfixes3:amd64.
# Preparing to unpack .../28-libxfixes3_1%3a5.0.3-2_amd64.deb ...
# 7Progress: [ 37%] [#####################.....................................] 8Unpacking libxfixes3:amd64 (1:5.0.3-2) ...
# Selecting previously unselected package libxshmfence1:amd64.
# Preparing to unpack .../29-libxshmfence1_1.3-1_amd64.deb ...
# 7Progress: [ 39%] [######################....................................] 8Unpacking libxshmfence1:amd64 (1.3-1) ...
# 7Progress: [ 39%] [######################....................................] 8Selecting previously unselected package libxxf86vm1:amd64.
# Preparing to unpack .../30-libxxf86vm1_1%3a1.1.4-1build1_amd64.deb ...
# Unpacking libxxf86vm1:amd64 (1:1.1.4-1build1) ...
# 7Progress: [ 41%] [#######################...................................] 8Selecting previously unselected package libglx-mesa0:amd64.
# Preparing to unpack .../31-libglx-mesa0_21.2.6-0ubuntu0.1~20.04.2_amd64.deb ...
# 7Progress: [ 41%] [#######################...................................] 8Unpacking libglx-mesa0:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Selecting previously unselected package libwayland-client0:amd64.
# Preparing to unpack .../32-libwayland-client0_1.18.0-1_amd64.deb ...
# 7Progress: [ 42%] [########################..................................] 8Unpacking libwayland-client0:amd64 (1.18.0-1) ...
# 7Progress: [ 43%] [#########################.................................] 8Selecting previously unselected package libxcb-randr0:amd64.
# Preparing to unpack .../33-libxcb-randr0_1.14-2_amd64.deb ...
# Unpacking libxcb-randr0:amd64 (1.14-2) ...
# 7Progress: [ 44%] [#########################.................................] 8Selecting previously unselected package mesa-vulkan-drivers:amd64.
# Preparing to unpack .../34-mesa-vulkan-drivers_21.2.6-0ubuntu0.1~20.04.2_amd64.deb ...
# 7Progress: [ 45%] [##########################................................] 8Unpacking mesa-vulkan-drivers:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Selecting previously unselected package libglvnd0:amd64.
# Preparing to unpack .../35-libglvnd0_1.3.2-1~ubuntu0.20.04.2_amd64.deb ...
# 7Progress: [ 46%] [##########################................................] 8Unpacking libglvnd0:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# 7Progress: [ 47%] [###########################...............................] 8Selecting previously unselected package libglx0:amd64.
# Preparing to unpack .../36-libglx0_1.3.2-1~ubuntu0.20.04.2_amd64.deb ...
# Unpacking libglx0:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# 7Progress: [ 48%] [############################..............................] 8Selecting previously unselected package libgl1:amd64.
# Preparing to unpack .../37-libgl1_1.3.2-1~ubuntu0.20.04.2_amd64.deb ...
# 7Progress: [ 49%] [############################..............................] 8Unpacking libgl1:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Setting up libx11-xcb1:amd64 (2:1.6.9-2ubuntu1.2) ...
# 7Progress: [ 50%] [#############################.............................] 8Setting up libpciaccess0:amd64 (0.16-0ubuntu1) ...
# 7Progress: [ 52%] [#############################.............................] 87Progress: [ 52%] [##############################............................] 8Setting up libxau6:amd64 (1:1.0.9-0ubuntu1) ...
# 7Progress: [ 54%] [###############################...........................] 8Setting up libxdmcp6:amd64 (1:1.1.3-0ubuntu1) ...
# 7Progress: [ 54%] [###############################...........................] 8Setting up libxcb1:amd64 (1.14-2) ...
# 7Progress: [ 56%] [################################..........................] 87Progress: [ 56%] [################################..........................] 8Setting up libxcb-xfixes0:amd64 (1.14-2) ...
# 7Progress: [ 58%] [#################################.........................] 8Setting up libglvnd0:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# 7Progress: [ 58%] [#################################.........................] 8Setting up libxcb-glx0:amd64 (1.14-2) ...
# 7Progress: [ 59%] [##################################........................] 87Progress: [ 60%] [##################################........................] 8Setting up libsensors-config (1:3.6.0-2ubuntu1.1) ...
# 7Progress: [ 61%] [###################################.......................] 8Setting up libxcb-shm0:amd64 (1.14-2) ...
# 7Progress: [ 62%] [####################################......................] 8Setting up libxcb-present0:amd64 (1.14-2) ...
# 7Progress: [ 63%] [####################################......................] 87Progress: [ 64%] [#####################################.....................] 8Setting up libx11-data (2:1.6.9-2ubuntu1.2) ...
# 7Progress: [ 65%] [#####################################.....................] 8Setting up libxcb-sync1:amd64 (1.14-2) ...
# 7Progress: [ 66%] [######################################....................] 8Setting up libllvm12:amd64 (1:12.0.0-3ubuntu1~20.04.5) ...
# 7Progress: [ 67%] [#######################################...................] 8Setting up libsensors5:amd64 (1:3.6.0-2ubuntu1.1) ...
# 7Progress: [ 69%] [#######################################...................] 87Progress: [ 69%] [########################################..................] 8Setting up libglapi-mesa:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# 7Progress: [ 71%] [########################################..................] 8Setting up libvulkan1:amd64 (1.2.131.2-1) ...
# 7Progress: [ 71%] [#########################################.................] 8Setting up libxcb-dri2-0:amd64 (1.14-2) ...
# 7Progress: [ 73%] [##########################################................] 87Progress: [ 73%] [##########################################................] 8Setting up libxshmfence1:amd64 (1.3-1) ...
# 7Progress: [ 75%] [###########################################...............] 8Setting up libxcb-randr0:amd64 (1.14-2) ...
# 7Progress: [ 75%] [###########################################...............] 8Setting up libx11-6:amd64 (2:1.6.9-2ubuntu1.2) ...
# 7Progress: [ 76%] [############################################..............] 87Progress: [ 77%] [############################################..............] 8Setting up libdrm-common (2.4.107-8ubuntu1~20.04.2) ...
# 7Progress: [ 78%] [#############################################.............] 8Setting up libelf1:amd64 (0.176-1.1build1) ...
# 7Progress: [ 79%] [#############################################.............] 8Setting up libwayland-client0:amd64 (1.18.0-1) ...
# 7Progress: [ 80%] [##############################################............] 87Progress: [ 81%] [###############################################...........] 8Setting up libxcb-dri3-0:amd64 (1.14-2) ...
# 7Progress: [ 82%] [###############################################...........] 8Setting up libxext6:amd64 (2:1.3.4-0ubuntu1) ...
# 7Progress: [ 83%] [################################################..........] 8Setting up libxxf86vm1:amd64 (1:1.1.4-1build1) ...
# 7Progress: [ 84%] [################################################..........] 8Setting up libxfixes3:amd64 (1:5.0.3-2) ...
# 7Progress: [ 86%] [#################################################.........] 87Progress: [ 86%] [##################################################........] 8Setting up libdrm2:amd64 (2.4.107-8ubuntu1~20.04.2) ...
# 7Progress: [ 88%] [##################################################........] 8Setting up libdrm-amdgpu1:amd64 (2.4.107-8ubuntu1~20.04.2) ...
# 7Progress: [ 88%] [###################################################.......] 8Setting up mesa-vulkan-drivers:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# 7Progress: [ 90%] [###################################################.......] 87Progress: [ 90%] [####################################################......] 8Setting up libdrm-nouveau2:amd64 (2.4.107-8ubuntu1~20.04.2) ...
# 7Progress: [ 92%] [#####################################################.....] 8Setting up libdrm-radeon1:amd64 (2.4.107-8ubuntu1~20.04.2) ...
# 7Progress: [ 92%] [#####################################################.....] 8Setting up libdrm-intel1:amd64 (2.4.107-8ubuntu1~20.04.2) ...
# 7Progress: [ 93%] [######################################################....] 87Progress: [ 94%] [######################################################....] 8Setting up libgl1-mesa-dri:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# 7Progress: [ 95%] [#######################################################...] 8Setting up libglx-mesa0:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# 7Progress: [ 96%] [#######################################################...] 8Setting up libglx0:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# 7Progress: [ 97%] [########################################################..] 87Progress: [ 98%] [########################################################..] 8Setting up libgl1:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# 7Progress: [ 99%] [#########################################################.] 8Processing triggers for libc-bin (2.31-0ubuntu9.2) ...
#
# 78Collecting opencv-python
#   Downloading opencv_python-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.9 MB)
#      ━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━ 29.3/60.9 MB 40.6 kB/s eta 0:12:57^C
#      ━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━ 29.3/60.9 MB 40.6 kB/s eta 0:12:57
# ERROR: Operation cancelled by user

# %% [markdown]
# - enable module autoreload and fix an import bug

# %%
# %load_ext autoreload
# %autoreload 2


import sys,os
sys.path.append(os.getcwd() + '/scripts')

# %% [markdown]
# - import the scripts and data

# %%
from scripts import data, model
import glob
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import cv2
from DataGenerator import DataGenerator

# %% [markdown]
# - slice each image to small samples of size 188*188
# - imgs -> rgb image
# - mask -> mask
# - edge -> edge_mask

# %%
_batch_size = 8

database1 = "data_platlets"

train_img_tile_files = sorted(glob.glob(f'{database1}/train/tiles/*.jpg'))
train_mask_tile_label_files = sorted(glob.glob(f'{database1}/train/mask/tiles/*.jpg'))


database2 = "data_platlets"

test_img_tile_files = sorted(glob.glob(f'{database2}/test/tiles/*.jpg'))
test_mask_tile_label_files = sorted(glob.glob(f'{database2}/test/mask/tiles/*.jpg'))


train_gen = DataGenerator(train_img_tile_files, train_mask_tile_label_files, None, _batch_size, skip_empty = True, skip_empty_mask = True, noise_prob=0)

test_gen = DataGenerator(test_img_tile_files, test_mask_tile_label_files, None, _batch_size, skip_empty = True, skip_empty_mask = True, augment=False)
# Out:
# skipping empty images with keep probability of 0.05
# before skip we have 32462 images
# 100%|██████████| 32462/32462 [00:00<00:00, 34230.14it/s]
# after skip we have 3148 images
# skipping empty images with keep probability of 0.05
# before skip we have 18228 images
# 100%|██████████| 18228/18228 [00:00<00:00, 33561.28it/s]
# after skip we have 1481 images

# %%
image, mask = train_gen.__getitem__(17)

data.plot_ime(image, mask, mask)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# - model parameters

# %%
_epochs = 50
_workers = 8
loss_func = "BinaryCrossentropy"
_model_name = f'PLT_{loss_func}_{_epochs}'
images_per_epoch = 1000
train_steps = images_per_epoch//_batch_size
#validation_steps = len(test_img_files)//_batch_size

Train = True

# %% [markdown]
# - load model and compile it

# %%
_model_name = "PLT_BinaryCrossentropy_50"

# %%
objects = {
    "tversky_loss":model.tversky_loss,
    "mean_iou": model.mean_iou,
    "dsc":model.dsc,
    "tversky":model.tversky,
    "tversky_b":model.tversky_b,
    "acc": tf.keras.metrics.Accuracy,
    "tversky_loss_b": model.tversky_loss_b
}


unet = tf.keras.models.load_model(f'./models/{_model_name}', custom_objects=objects)

unet.compile(optimizer="adam",
             loss="BinaryCrossentropy",
             metrics=[model.mean_iou, model.dsc, model.tversky, model.tversky_b, 'acc'])

#unet.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7860/3278385775.py in <module>
#       1 objects = {
# ----> 2     "tversky_loss":model.tversky_loss,
#       3     "mean_iou": model.mean_iou,
#       4     "dsc":model.dsc,
#       5     "tversky":model.tversky,
#
# NameError: name 'model' is not defined

# %% [markdown]
# - Evaluate

# %%
unet.evaluate(test_gen)

# %% [markdown]
# - create the model and compile it

# %%
unet = model.get_do_unet_WBC(compile = False)

unet.compile(optimizer="adam",
             loss="BinaryCrossentropy",
             metrics=[model.mean_iou, model.dsc, model.tversky, model.tversky_b, 'acc'])

#unet.summary()

# %% [markdown]
# - load weights

# %%
unet.load_weights(f"models/....h5")

# %% [markdown]
# - Train the model

# %%
_model_name = _model_name + "_plus_epochs"

# %%
if Train:
    try:
        os.remove(f"models/{_model_name}_best.h5")
        os.remove(f"models/{_model_name}_all.h5")
    except:
        pass
    
    history = unet.fit(train_gen, 
            epochs=_epochs, 
            validation_data=train_gen, 
            steps_per_epoch=train_steps,
            max_queue_size=10*_workers,
            use_multiprocessing=True,
            workers=_workers,
            verbose=1,
            callbacks=model.get_callbacks(_model_name))
    # saving the model in tensorflow format
    unet.save(f'./models/{_model_name}',save_format='tf')
# Out:
# Epoch 1/20
# 125/125 [==============================] - ETA: 0s - loss: 0.1725 - mean_iou: 0.0432 - dsc: 0.0600 - tversky: 0.0847 - tversky_b: 0.2295 - acc: 0.9749
# Epoch 00001: val_loss improved from inf to 0.17177, saving model to models/PLT_BinaryCrossentropy_20_best.h5
# 125/125 [==============================] - 38s 278ms/step - loss: 0.1725 - mean_iou: 0.0432 - dsc: 0.0600 - tversky: 0.0847 - tversky_b: 0.2295 - acc: 0.9749 - val_loss: 0.1718 - val_mean_iou: 0.0000e+00 - val_dsc: 0.0236 - val_tversky: 0.0345 - val_tversky_b: 0.0436 - val_acc: 0.9880
# Epoch 2/20
# 125/125 [==============================] - ETA: 0s - loss: 0.0739 - mean_iou: 0.0158 - dsc: 0.0618 - tversky: 0.0791 - tversky_b: 0.1022 - acc: 0.9879
# Epoch 00002: val_loss improved from 0.17177 to 0.06546, saving model to models/PLT_BinaryCrossentropy_20_best.h5
# 125/125 [==============================] - 35s 273ms/step - loss: 0.0739 - mean_iou: 0.0158 - dsc: 0.0618 - tversky: 0.0791 - tversky_b: 0.1022 - acc: 0.9879 - val_loss: 0.0655 - val_mean_iou: 0.0011 - val_dsc: 0.0414 - val_tversky: 0.0492 - val_tversky_b: 0.0234 - val_acc: 0.9879
# Epoch 3/20
# 125/125 [==============================] - ETA: 0s - loss: 0.0480 - mean_iou: 0.0636 - dsc: 0.1913 - tversky: 0.2246 - tversky_b: 0.3642 - acc: 0.9895
# Epoch 00003: val_loss improved from 0.06546 to 0.05604, saving model to models/PLT_BinaryCrossentropy_20_best.h5
# 125/125 [==============================] - 35s 278ms/step - loss: 0.0480 - mean_iou: 0.0636 - dsc: 0.1913 - tversky: 0.2246 - tversky_b: 0.3642 - acc: 0.9895 - val_loss: 0.0560 - val_mean_iou: 0.0689 - val_dsc: 0.1554 - val_tversky: 0.1929 - val_tversky_b: 0.3890 - val_acc: 0.9908
# Epoch 4/20
# 125/125 [==============================] - ETA: 0s - loss: 0.0374 - mean_iou: 0.1210 - dsc: 0.3039 - tversky: 0.3441 - tversky_b: 0.5314 - acc: 0.9911
# Epoch 00004: val_loss improved from 0.05604 to 0.03965, saving model to models/PLT_BinaryCrossentropy_20_best.h5
# 125/125 [==============================] - 35s 273ms/step - loss: 0.0374 - mean_iou: 0.1210 - dsc: 0.3039 - tversky: 0.3441 - tversky_b: 0.5314 - acc: 0.9911 - val_loss: 0.0396 - val_mean_iou: 0.0958 - val_dsc: 0.2530 - val_tversky: 0.2869 - val_tversky_b: 0.4606 - val_acc: 0.9914
# Epoch 5/20
# 125/125 [==============================] - ETA: 0s - loss: 0.0340 - mean_iou: 0.1070 - dsc: 0.3288 - tversky: 0.3583 - tversky_b: 0.5184 - acc: 0.9907
# Epoch 00005: val_loss did not improve from 0.03965
# 125/125 [==============================] - 34s 272ms/step - loss: 0.0340 - mean_iou: 0.1070 - dsc: 0.3288 - tversky: 0.3583 - tversky_b: 0.5184 - acc: 0.9907 - val_loss: 0.0431 - val_mean_iou: 0.0374 - val_dsc: 0.2187 - val_tversky: 0.2181 - val_tversky_b: 0.2798 - val_acc: 0.9903
# Epoch 6/20
# 125/125 [==============================] - ETA: 0s - loss: 0.
20
# 125/125 [==============================] - ETA: 0s - loss: 0.0224 - mean_iou: 0.1933 - dsc: 0.5265 - tversky: 0.5403 - tversky_b: 0.6550 - acc: 0.9935
# Epoch 00017: val_loss improved from 0.02326 to 0.02245, saving model to models/PLT_BinaryCrossentropy_20_best.h5
# 125/125 [==============================] - 35s 278ms/step - loss: 0.0224 - mean_iou: 0.1933 - dsc: 0.5265 - tversky: 0.5403 - tversky_b: 0.6550 - acc: 0.9935 - val_loss: 0.0224 - val_mean_iou: 0.2359 - val_dsc: 0.5515 - val_tversky: 0.5948 - val_tversky_b: 0.7153 - val_acc: 0.9932
# Epoch 18/20
# 125/125 [==============================] - ETA: 0s - loss: 0.0221 - mean_iou: 0.1902 - dsc: 0.5322 - tversky: 0.5475 - tversky_b: 0.6608 - acc: 0.9934
# Epoch 00018: val_loss did not improve from 0.02245
# 125/125 [==============================] - 35s 276ms/step - loss: 0.0221 - mean_iou: 0.1902 - dsc: 0.5322 - tversky: 0.5475 - tversky_b: 0.6608 - acc: 0.9934 - val_loss: 0.0253 - val_mean_iou: 0.1253 - val_dsc: 0.4654 - val_tversky: 0.4578 - val_tversky_b: 0.5635 - val_acc: 0.9930
# Epoch 19/20
# 125/125 [==============================] - ETA: 0s - loss: 0.0213 - mean_iou: 0.1952 - dsc: 0.5525 - tversky: 0.5629 - tversky_b: 0.6755 - acc: 0.9940
# Epoch 00019: val_loss did not improve from 0.02245
# 125/125 [==============================] - 35s 276ms/step - loss: 0.0213 - mean_iou: 0.1952 - dsc: 0.5525 - tversky: 0.5629 - tversky_b: 0.6755 - acc: 0.9940 - val_loss: 0.0252 - val_mean_iou: 0.1981 - val_dsc: 0.5400 - val_tversky: 0.5467 - val_tversky_b: 0.6320 - val_acc: 0.9911
# Epoch 20/20
# 125/125 [==============================] - ETA: 0s - loss: 0.0221 - mean_iou: 0.1918 - dsc: 0.5379 - tversky: 0.5491 - tversky_b: 0.6616 - acc: 0.9937
# Epoch 00020: val_loss did not improve from 0.02245
# 125/125 [==============================] - 35s 274ms/step - loss: 0.0221 - mean_iou: 0.1918 - dsc: 0.5379 - tversky: 0.5491 - tversky_b: 0.6616 - acc: 0.9937 - val_loss: 0.0235 - val_mean_iou: 0.2240 - val_dsc: 0.5133 - val_tversky: 0.5484 - val_tversky_b: 0.6682 - val_acc: 0.9934
# INFO:tensorflow:Assets written to: ./models/PLT_BinaryCrossentropy_20/assets

# %% [markdown]
# - save the training log

# %%
#save the training log into a file
import json
with open(f"models/{_model_name}_log.json", "w+") as fp:
    json.dump(history.history,fp)

# Opening JSON file
with open(f"models/{_model_name}_log.json") as fp:
    # returns JSON object as
    # a dictionary
    loaded_hist = json.load(fp)

# %%
#rand_index = np.random.randint(0, len(test_img_chips), 1)[0]
#img = test_img_chips[rand_index]
#mask = np.squeeze(test_mask_chips[rand_index])
#edge = np.squeeze(test_edge_chips[rand_index])

test_img_chips, test_mask_chips = test_gen.__getitem__(35)


prediction = unet.predict(test_img_chips)


data.plot_ime(test_img_chips, prediction[0])

# %% [markdown]
# - predict full image

# %%
images, masks = model.predictFullImage(unet,
                        data.load_data_na(sorted(glob.glob(f'data_platlets/test/*.jpg'))[:20], RGB=True, clahe=True),
                        padding=100,
                        input_size=188,
                        output_size=100,
                        normalize_output = False,
                        edge = False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1402/2259728208.py in <module>
# ----> 1 images, masks = model.predictFullImage(unet,
#       2                         data.load_data_na(sorted(glob.glob(f'data_platlets/test/*.jpg'))[:20], RGB=True, clahe=True),
#       3                         padding=100,
#       4                         input_size=188,
#       5                         output_size=100,
#
# /notebooks/scripts/model.py in predictFullImage(model, imgs, padding, input_size, output_size, normalize_input, normalize_output, edge)
#     419             mask_slices = prediction
#     420
# --> 421         mask_slices_2d = mask_slices.reshape((img_sizes[0][0], img_sizes[0][1], 100, 100, 1))
#     422
#     423         if edge:
#
# ValueError: cannot reshape array of size 10000 into shape (21,28,100,100,1)

# %%
data.plot_ime(images,
              masks,
              masks,
              figSize=(25,15))

# %% [markdown]
# ## model training data plot

# %%
hist = history.history

lines = 4
columns = 3

fig = plt.figure(figsize=(20, 20), dpi=80)
fig.subplots_adjust(hspace=0.3, wspace=0.3)
fig_num = 1
ax = fig.add_subplot(lines, columns, fig_num)
ax.set_title("mask accuracy")
ax.plot(hist['mask_acc'], label="Training")
ax.plot(hist['val_mask_acc'], label="Validation")
ax.legend()
fig_num = fig_num + 1
ax = fig.add_subplot(lines, columns, fig_num)
ax.set_title("edge mask accuracy")
ax.plot(hist['edge_acc'], label="Training")
ax.plot(hist['val_edge_acc'], label="Validation")
ax.legend()
fig_num = fig_num + 2
ax = fig.add_subplot(lines, columns, fig_num)
ax.set_title("mask loss")
ax.plot(hist['mask_loss'], label="Training")
ax.plot(hist['val_mask_loss'], label="Validation")
ax.legend()
fig_num = fig_num + 1
ax = fig.add_subplot(lines, columns, fig_num)
ax.set_title("edge loss")
ax.plot(hist['edge_loss'], label="Training")
ax.plot(hist['val_edge_loss'], label="Validation")
ax.legend()

fig_num = fig_num + 1
ax = fig.add_subplot(lines, columns, fig_num)
ax.set_title("global loss")
ax.plot(hist['loss'], label="Training")
ax.plot(hist['val_loss'], label="Validation")
ax.legend()


fig_num = fig_num + 1
ax = fig.add_subplot(lines, columns, fig_num)
ax.set_title("mask metrics")
ax.plot(hist['mask_dsc'], label="dsc")
ax.plot(hist['mask_mean_iou'], label="mean iou")
ax.plot(hist['mask_tversky'], label="tversky")
ax.plot(hist['mask_acc'], label="accuracy")

ax.set_title("mask metrics")
ax.plot(hist['val_mask_dsc'], label="val_dsc")
ax.plot(hist['val_mask_mean_iou'], label="val_mean iou")
ax.plot(hist['val_mask_tversky'], label="val_tversky")
ax.plot(hist['val_mask_acc'], label="val_accuracy")

fig_num = fig_num + 1
ax = fig.add_subplot(lines, columns, fig_num)
ax.set_title("edge metrics")
ax.plot(hist['edge_dsc'], label="dsc")
ax.plot(hist['edge_mean_iou'], label="mean iou")
ax.plot(hist['edge_tversky'], label="tversky")
ax.plot(hist['edge_acc'], label="accuracy")

ax.set_title("edge metrics")
ax.plot(hist['val_edge_dsc'], label="val_dsc")
ax.plot(hist['val_edge_mean_iou'], label="val_mean iou")
ax.plot(hist['val_edge_tversky'], label="val_tversky")
ax.plot(hist['val_edge_acc'], label="val_accuracy")
ax.legend()

# %% [markdown]
# ## For Debugging
# - show in between layers output

# %%
ind = np.random.randint(0, 32, 1)[0]

_pool1 = pool1[:-1,:-1,ind]
_pool2 = pool2[:-1,:-1,ind]
_pool3 = pool3[:-1,:-1,ind]
_down4 = down4[:-1,:-1,ind]
_up1 = up1[:-1,:-1,ind]
_up2 = up2[:-1,:-1,ind]
_up3 = up3[:-1,:-1,ind]

fig = plt.figure(figsize=(15, 10), dpi=80)
fig.subplots_adjust(hspace=0.3, wspace=0.3)
fig_num = 1
ax = fig.add_subplot(3, 3, fig_num)
ax.set_title("out_mask")
ax.imshow(out_mask)
fig_num = fig_num + 1
ax = fig.add_subplot(3, 3, fig_num)
ax.set_title("out_edge")
ax.imshow(out_edge)
fig_num = fig_num + 1
ax = fig.add_subplot(3, 3, fig_num)
ax.set_title("pool1")
ax.imshow(_pool1)
fig_num = fig_num + 1
ax = fig.add_subplot(3, 3, fig_num)
ax.set_title("pool2")
ax.imshow(_pool2)
fig_num = fig_num + 1
ax = fig.add_subplot(3, 3, fig_num)
ax.set_title("pool3")
ax.imshow(_pool3)
fig_num = fig_num + 1
ax = fig.add_subplot(3, 3, fig_num)
ax.set_title("down4")
ax.imshow(_down4)
fig_num = fig_num + 1
ax = fig.add_subplot(3, 3, fig_num)
ax.set_title("up1")
ax.imshow(_up1)
fig_num = fig_num + 1
ax = fig.add_subplot(3, 3, fig_num)
ax.set_title("up2")
ax.imshow(_up2)
fig_num = fig_num + 1
ax = fig.add_subplot(3, 3, fig_num)
ax.set_title("up3")
ax.imshow(_up3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/zaxo7/WorkSpace/DEEP LEARNING/MY-U-NET/test.ipynb Cell 22' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/home/zaxo7/WorkSpace/DEEP%20LEARNING/MY-U-NET/test.ipynb#ch0000022?line=0'>1</a> ind = np.random.randint(0, 32, 1)[0]
# ----> <a href='vscode-notebook-cell:/home/zaxo7/WorkSpace/DEEP%20LEARNING/MY-U-NET/test.ipynb#ch0000022?line=2'>3</a> _pool1 = pool1[:-1,:-1,ind]
#       <a href='vscode-notebook-cell:/home/zaxo7/WorkSpace/DEEP%20LEARNING/MY-U-NET/test.ipynb#ch0000022?line=3'>4</a> _pool2 = pool2[:-1,:-1,ind]
#       <a href='vscode-notebook-cell:/home/zaxo7/WorkSpace/DEEP%20LEARNING/MY-U-NET/test.ipynb#ch0000022?line=4'>5</a> _pool3 = pool3[:-1,:-1,ind]
#
# NameError: name 'pool1' is not defined

# %% [markdown]
# - function to plot and array of images of shape (width, height, n_images)

# %%
def picshow(img, title):
    num = img.shape[2]
    imgs_per_line = 4
    ax = num//imgs_per_line + 1
    ay = imgs_per_line
    fig =plt.figure(figsize=(30, num//imgs_per_line * 10))
    fig.subplots_adjust(hspace=0.1, wspace=0.1)
    for i in range(1,num + 1):
        sub = fig.add_subplot(ax,ay,i)
        sub.set_title(f"{title} {i}")
        sub.imshow(img[:-1,:-1,i - 1])
    plt.show()

# %%
picshow(pool1, 'pool1 ')
picshow(pool2, 'pool2 ')
picshow(pool3, 'pool3 ')
picshow(down4, 'down4 ')
picshow(up1, 'up1 ')
picshow(up2, 'up2 ')
picshow(up3, 'up3 ')
